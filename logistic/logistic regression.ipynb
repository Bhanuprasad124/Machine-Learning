# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/BHANU PRASAD/OneDrive/Desktop/Data science/insurance_data.csv')

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
import matplotlib.pyplot as mp

# %%
# %matplotlib inline

# %%
mp.scatter(df.age,df.bought_insurance,c='r')
mp.xlabel('age')
mp.ylabel('insurance')
mp.title('scattered_plot',c='g')
# Out:
# Text(0.5, 1.0, 'scattered_plot')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['age']],df.bought_insurance,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lg.predict(x_test)
# Out:
# array([0, 1, 0, 1, 0, 1])

# %%
x_test
# Out:
#     age
# 19   18
# 24   50
# 10   18
# 9    61
# 11   28
# 2    47

# %%
lg.predict_proba(x_test)
# Out:
# array([[0.92114292, 0.07885708],
#        [0.22414595, 0.77585405],
#        [0.92114292, 0.07885708],
#        [0.07492273, 0.92507727],
#        [0.78614432, 0.21385568],
#        [0.29011507, 0.70988493]])
