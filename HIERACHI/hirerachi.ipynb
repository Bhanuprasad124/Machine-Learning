# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/BHANU PRASAD/OneDrive/Desktop/Data science/income.csv")

# %%
df.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000

# %%
df.rename(columns={'Income($)':'income'},inplace=True)

# %%
df.head()
# Out:
#       Name  Age  income
# 0      Rob   27   70000
# 1  Michael   29   90000
# 2    Mohan   29   61000
# 3   Ismail   28   60000
# 4     Kory   42  150000

# %%
plt.scatter(df.Age,df.income)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
df[['Age','income']]=scaler.fit_transform(df[['Age','income']])

# %%
df.head()
# Out:
#       Name       Age    income
# 0      Rob  0.058824  0.213675
# 1  Michael  0.176471  0.384615
# 2    Mohan  0.176471  0.136752
# 3   Ismail  0.117647  0.128205
# 4     Kory  0.941176  0.897436

# %%
from sklearn.cluster   import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram ,linkage

# %%
dendrogram(linkage(df[['Age','income']],method='ward'))
# Out:
# {'icoord': [[25.0, 25.0, 35.0, 35.0],
#   [55.0, 55.0, 65.0, 65.0],
#   [75.0, 75.0, 85.0, 85.0],
#   [60.0, 60.0, 80.0, 80.0],
#   [45.0, 45.0, 70.0, 70.0],
#   [30.0, 30.0, 57.5, 57.5],
#   [15.0, 15.0, 43.75, 43.75],
#   [5.0, 5.0, 29.375, 29.375],
#   [95.0, 95.0, 105.0, 105.0],
#   [135.0, 135.0, 145.0, 145.0],
#   [125.0, 125.0, 140.0, 140.0],
#   [115.0, 115.0, 132.5, 132.5],
#   [100.0, 100.0, 123.75, 123.75],
#   [155.0, 155.0, 165.0, 165.0],
#   [175.0, 175.0, 185.0, 185.0],
#   [205.0, 205.0, 215.0, 215.0],
#   [195.0, 195.0, 210.0, 210.0],
#   [180.0, 180.0, 202.5, 202.5],
#   [160.0, 160.0, 191.25, 191.25],
#   [111.875, 111.875, 175.625, 175.625],
#   [17.1875, 17.1875, 143.75, 143.75]],
#  'dcoord': [[0.0, 0.06416907205484963, 0.06416907205484963, 0.0],
#   [0.0, 0.05944122279663656, 0.05944122279663656, 0.0],
#   [0.0, 0.06020442808828668, 0.06020442808828668, 0.0],
#   [0.05944122279663656,
#    0.12389477790020703,
#    0.12389477790020703,
# ...

# %%
agg=AgglomerativeClustering(n_clusters=3)

# %%
agg.fit(df[['Age','income']])
# Out:
# AgglomerativeClustering(n_clusters=3)

# %%
df['clusters']=agg.labels_

# %%
df.head()
# Out:
#       Name       Age    income  clusters
# 0      Rob  0.058824  0.213675         1
# 1  Michael  0.176471  0.384615         1
# 2    Mohan  0.176471  0.136752         1
# 3   Ismail  0.117647  0.128205         1
# 4     Kory  0.941176  0.897436         0

# %%
plt.scatter(df['Age'],df['income'],c=agg.labels_)
