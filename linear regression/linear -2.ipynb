# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\BHANU PRASAD\OneDrive\Desktop\Data science\Housing.csv')

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()

# %%
cat_values=['mainroad',	'guestroom'	,'basement'	,'hotwaterheating',	'airconditioning'	,'prefarea'	,'furnishingstatus']

# %%
for i in cat_values:
    df[i]=label.fit_transform(df[i])

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.area,df.price)

# %%
x=df.drop('price',axis=1)

# %%
y=df.price

# %%
#from the above we know that the data is not in linear manner 
#so we need to use the polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=4)
x_poly=poly.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x_poly,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_train,y_train)
# Out:
# 0.940135439771582

# %%
reg.score(x_test,y_test)
# Out:
# -126.40970571209134

# %%
y_test
# Out:
# 39     7910000
# 16     9100000
# 130    5866000
# 353    3780000
# 510    2520000
#         ...
# 179    5215000
# 350    3780000
# 224    4760000
# 203    4900000
# 325    4007500
# Name: price, Length: 109, dtype: int64

# %%
x_test
# Out:
# array([[1.000e+00, 6.000e+03, 4.000e+00, ..., 0.000e+00, 0.000e+00,
#         1.000e+00],
#        [1.000e+00, 6.600e+03, 4.000e+00, ..., 4.000e+00, 8.000e+00,
#         1.600e+01],
#        [1.000e+00, 4.800e+03, 3.000e+00, ..., 0.000e+00, 0.000e+00,
#         1.600e+01],
#        ...,
#        [1.000e+00, 1.024e+04, 2.000e+00, ..., 4.000e+00, 8.000e+00,
#         1.600e+01],
#        [1.000e+00, 5.400e+03, 4.000e+00, ..., 0.000e+00, 0.000e+00,
#         1.000e+00],
#        [1.000e+00, 3.460e+03, 4.000e+00, ..., 0.000e+00, 0.000e+00,
#         1.000e+00]])

# %%
reg.predict(x_test)
# Out:
# array([ 8.40957442e+06,  1.83314251e+07,  7.16401170e+06,  5.31448044e+06,
#         2.59609973e+06,  1.33316668e+07, -2.99172968e+06, -2.03482017e+08,
#         9.29091275e+06,  6.21070473e+06,  4.61904559e+06,  4.52687662e+06,
#         1.91187145e+06,  4.79217485e+06,  3.92172636e+06,  2.97055389e+06,
#         2.67376900e+06,  2.91750389e+06,  7.28466497e+06,  5.12293785e+06,
#         4.24460881e+06,  3.74900748e+06,  1.49786278e+07,  7.01330049e+06,
#         4.87915263e+06,  5.49363510e+06,  6.40294566e+06,  2.14968738e+06,
#         2.32120966e+06,  1.32897428e+07,  9.44648755e+06,  1.05105791e+07,
#         4.84206187e+06,  3.28386567e+06,  4.48728415e+06,  4.33415287e+06,
#         2.84018285e+06,  4.96172663e+06,  2.99882462e+06,  4.46157649e+06,
#         8.08460393e+06,  5.60049929e+06,  3.07690902e+06,  3.02059409e+06,
#         7.94988989e+06,  2.94319623e+06,  2.42090820e+06,  1.95037195e+06,
# ...

# %%
# reg.score(x_poly)

# %%
le=LinearRegression()

# %%
le.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
le.predict(X_test)
# Out:
# array([7376822.31617924, 4070105.56628193, 4890721.97279102,
#        7509276.53931995, 3233933.18821542, 7396692.44327271,
#        2780707.7549379 , 6538541.47520984, 7612188.68203553,
#        4647735.06928209, 5990483.48343861, 3516469.79742363,
#        2586327.20018626, 5980042.62783405, 6915282.4728626 ,
#        3743089.45774318, 6288840.28266029, 5600740.63962051,
#        3378572.65635385, 4739266.32552616, 4369336.52351201,
#        5501204.15402653, 3794127.14443395, 5161245.48155334,
#        5865248.76761114, 3168352.37803245, 5934196.44837097,
#        3281278.44811398, 5355318.35965928, 2659047.578646  ,
#        3406644.29983083, 3960599.90091336, 2261225.05833607,
#        5507813.65476286, 3475535.12585762, 3654283.76385868,
#        5246597.5091755 , 3498812.90778402, 7534778.71410006,
#        7178231.67246962, 4496526.37657755, 7212257.08952145,
#        5851924.00058189, 8356293.4144601 , 4133568.80023538,
# ...

# %%
X_train, X_test, y_train, y_test =train_test_split(x,y,train_size=0.2)

# %%
le.score(X_test,y_test)
# Out:
# 0.6243529941960827

# %%
from sklearn.svm import SVR

# %%
svr=SVR(kernel='linear',degree=4)

# %%
svr.fit(X_train,y_train)
# Out:
# SVR(degree=4, kernel='linear')

# %%
svr.score(X_train,y_train)
# Out:
# 0.340241009569496
