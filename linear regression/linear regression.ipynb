# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as mp
from sklearn import linear_model

# %%
import seaborn as sb

# %%
df=pd.read_excel("C:/Users/BHANU PRASAD/OneDrive/Documents/price.xlsx")

# %%
df
# Out:
#    area   price
# 0   2500  20000
# 1   3000  30000
# 2   3500  40000
# 3   4000  50000
# 4   4500  60000
# 5   5000  70000

# %%
# df.plot(kind='bar')

# %%
# %matplotlib inline

# %%
df.columns
# Out:
# Index(['area ', 'price'], dtype='object')

# %%
mp.scatter(df['area '],df.price,color="red")
mp.xlabel('area')
mp.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
reg=linear_model.LinearRegression()

# %%
df.columns
# Out:
# Index(['area ', 'price'], dtype='object')

# %%
# df.rename(columns={'area ':'area'}, inplace=True)
df.columns=df.columns.str.strip()

# %%
reg.fit(df[['area']],df['price'])
# Out:
# LinearRegression()

# %%
reg.predict([[6000]])
# Out:
# C:\Users\BHANU PRASAD\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([90000.])

# %%
reg.intercept_
# Out:
# -29999.999999999985

# %%
reg.coef_
# Out:
# array([20.])

# %%
20*6000-30000
# Out:
# 90000

# %%
reg.predict([[5500]])
# Out:
# C:\Users\BHANU PRASAD\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([80000.])

# %%
from sklearn.svm import SVR

# %%
svm=SVR(kernel='linear')

# %%
svm.fit(df[['area']],df['price'])
# Out:
# SVR(kernel='linear')

# %%
svm.predict([[6000]])
# Out:
# C:\Users\BHANU PRASAD\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([89999.82])

# %%
svm.predict([[5500]])
# Out:
# C:\Users\BHANU PRASAD\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([79999.86])

# %%
svm.score(df[['area']],df['price'])
# Out:
# 0.999999999984

# %%
reg.score(df[['area']],df['price'])
# Out:
# 1.0

# %%
svm=SVR(kernel='poly')

# %%
svm.fit(df[['area']],df['price'])
# Out:
# SVR(kernel='poly')

# %%
svm.predict([[5500]])
# Out:
# C:\Users\BHANU PRASAD\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([85113.9563736])

# %%
svm.score(df[['area']],df['price'])
# Out:
# 0.9260469613427309
